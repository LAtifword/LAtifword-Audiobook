# %% [markdown]
# # LATIF AI Voice Studio
# One-click interactive interface for manuscript upload, reference voice, cover art, metadata, WAV generation, and M4A packaging.
#
# Use only an authorized reference voice. The hosted Manus Charon voice cannot be exported; this interface uses SILMA TTS from the repository workflow.

# %%
# !apt-get -qq update && apt-get -qq install -y ffmpeg
# !pip -q install silma-tts gradio soundfile numpy
# !git clone -q --depth 1 --branch voice-lab-silma-audiobook https://github.com/LAtifword/LAtifword-Audiobook.git /content/latif-audiobook || true

# %%
# %cd /content/latif-audiobook/voice_lab
# !python colab_voice_studio.py
